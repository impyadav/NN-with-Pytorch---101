# %% [markdown]
# # FFNN - Feed Forward Neural Network

# %% [markdown]
# Part of **#30DaysOfBasics**, Lets implement a vanilla FFNN with pytorch

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader

# %%
#load the data

DATA_PATH = '../data/diabetes.csv'

df = pd.read_csv(DATA_PATH)

# %%
df.head()
# Out:
#    Number of times pregnant  Plasma glucose concentration  \
# 0                         6                           148
# 1                         1                            85
# 2                         8                           183
# 3                         1                            89
# 4                         0                           137
#
#    Diastolic blood pressure  Triceps skin fold thickness  \
# 0                        72                           35
# 1                        66                           29
# 2                        64                            0
# 3                        66                           23
# 4                        40                           35
#
#    2-Hour serum insulin  Body mass index  Age     Class
# 0                     0             33.6   50  positive
# 1                     0             26.6   31  negative
# 2                     0             23.3   32  positive
# 3                    94             28.1   21  negative
# 4                   168             43.1   33  positive

# %%
#class mapping to integer

df.class_int = df.Class.apply(lambda x: 1 if x == 'positive'else 0)
# Out:
# /var/folders/fm/r4mdm1_n5s5c4cvws96yn7qm0000gn/T/ipykernel_85216/1751678756.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.class_int = df.Class.apply(lambda x: 1 if x == 'positive'else 0)

# %%
#Seperate b/w X, y

X = df.iloc[:,0:-1].values

y = df.class_int.values


print(X.shape, y.shape)

#chang dtype of both

X = X.astype('float32')
y = y.astype('float32')
# Out:
# (768, 7) (768,)

# %%
#Make sure Y-label is in 2 dimension

y = torch.from_numpy(y)

y = torch.unsqueeze(y, 1)

print(y.shape)
# Out:
# torch.Size([768, 1])

# %%
#feature normalization

norm = StandardScaler()
X = norm.fit_transform(X)

print(X)
# Out:
# [[ 0.6399473   0.8483238   0.14964075 ... -0.6928905   0.20401257
#    1.4259955 ]
#  [-0.84488505 -1.1233964  -0.16054575 ... -0.6928905  -0.6844219
#   -0.1906719 ]
#  [ 1.2338802   1.9437239  -0.26394126 ... -0.6928905  -1.1032556
#   -0.10558414]
#  ...
#  [ 0.34298077  0.00330087  0.14964075 ...  0.27959374 -0.73518956
#   -0.27575967]
#  [-0.84488505  0.1597866  -0.47073224 ... -0.6928905  -0.24020454
#    1.1707321 ]
#  [-0.84488505 -0.8730192   0.04624526 ... -0.6928905  -0.20212887
#   -0.87137395]]

# %%
#creating the dataset for our custom data

class CustomDataset(Dataset):
    
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    
    def __getitem__(self, index):
        return self.x[index], self.y[index]
    
    
    def __len__(self):
        return len(self.x)

# %%
diabetesDataset = CustomDataset(X, y)

# %%
#load the dataset into torch's dataloader for batch and shuffling

train_loader = DataLoader(diabetesDataset, batch_size=64, shuffle=True)

print('No of batches: ',len(train_loader))

for feature, out in train_loader:
    print(len(feature), len(out))
    break
# Out:
# No of batches:  12
# 64 64

# %%
#Building the Neural Network

class CustomModel(nn.Module):
    
    def __init__(self, ip_features, op_features):
        super(CustomModel, self).__init__()
        self.ip_features = ip_features
        self.op_features = op_features
        
        self.fc1 = nn.Linear(ip_features, 5)
        self.fc2 = nn.Linear(5, 4)
        self.fc3 = nn.Linear(4, 3)
        self.fc4 = nn.Linear(3,op_features)
        
        self.tanh = nn.Tanh()
        self.sigmoid = nn.Sigmoid()
        
        
    def forward(self, x):
        out = self.fc1(x)
        out = self.tanh(out)
        
        out = self.fc2(out)
        out = self.tanh(out)
        
        out = self.fc3(out)
        out = self.tanh(out)
        
        out = self.fc4(out)
        out = self.sigmoid(out)
        
        return out

# %%
#declare loss and optimizer function

network = CustomModel(7,1)

#loss
criterion = nn.BCELoss(size_average=True)

#optimizer
optimizer = torch.optim.SGD(network.parameters(), lr=0.01, momentum=0.8)
# Out:
# /Users/impyadav/opt/anaconda3/envs/m1/lib/python3.9/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %%
#train the network

epochs = 300

for epoch in range(epochs):
    for feature, label in train_loader:
        
        #just to sure, everything is in float
        feature = feature.float()
        label = label.float()
        
        #forward prop
        outputs = network(feature)
        
        #loss
        loss = criterion(outputs, label)
        
        #clear gradient buffer
        optimizer.zero_grad()
        
        #calcuate gradients
        loss.backward()
        
        #update the weights
        optimizer.step()
        
    #Accuracy calcualtion
    op = (outputs>0.5).float()
    acc = (op == label).float().mean()
    print('{}/{} epoch: Accuracy is {:.3f} and loss is {:.3f}'.format(epoch, epochs, acc, loss))
# Out:
# 0/300 epoch: Accuracy is 0.781 and loss is 0.429
# 1/300 epoch: Accuracy is 0.688 and loss is 0.487
# 2/300 epoch: Accuracy is 0.750 and loss is 0.509
# 3/300 epoch: Accuracy is 0.844 and loss is 0.355
# 4/300 epoch: Accuracy is 0.812 and loss is 0.362
# 5/300 epoch: Accuracy is 0.797 and loss is 0.377
# 6/300 epoch: Accuracy is 0.844 and loss is 0.350
# 7/300 epoch: Accuracy is 0.859 and loss is 0.401
# 8/300 epoch: Accuracy is 0.750 and loss is 0.493
# 9/300 epoch: Accuracy is 0.797 and loss is 0.477
# 10/300 epoch: Accuracy is 0.781 and loss is 0.403
# 11/300 epoch: Accuracy is 0.750 and loss is 0.446
# 12/300 epoch: Accuracy is 0.828 and loss is 0.421
# 13/300 epoch: Accuracy is 0.797 and loss is 0.446
# 14/300 epoch: Accuracy is 0.781 and loss is 0.373
# 15/300 epoch: Accuracy is 0.859 and loss is 0.397
# 16/300 epoch: Accuracy is 0.844 and loss is 0.380
# 17/300 epoch: Accuracy is 0.891 and loss is 0.317
# 18/300 epoch: Accuracy is 0.797 and loss is 0.479
# 19/300 epoch: Accuracy is 0.719 and loss is 0.579
# 20/300 epoch: Accuracy is 0.859 and loss is 0.399
# 21/300 epoch: Accuracy is 0.828 and loss is 0.467
# 22/300 epoch: Accuracy is 0.703 and loss is 0.516
# 23/300 epoch: Accuracy is 0.766 and loss is 0.426
# 24/300 epoch: Accuracy is 0.828 and loss is 0.463
# 25/300 epoch: Accuracy is 0.750 and loss is 0.509
# 26/300 epoch: Accuracy is 0.734 and loss is 0.579
# 27/300 epoch: Accuracy is 0.875 and loss is 0.331
# 28/300 epoch: Accuracy is 0.734 and loss is 0.469
# 29/300 epoch: Accuracy is 0.766 and loss is 0.517
# 30/300 epoch: Accuracy is 0.859 and loss is 0.386
# 31/300 epoch: Accuracy is 0.766 and loss is 0.423
# 32/300 epoch: Accuracy is 0.766 and loss is 0.448
# 33/300 epoch: Accuracy is 0.844 and loss is 0.420
# 34/300 epoch: Accuracy is 0.734 and loss is 0.464
# 35/300 epoch: Accuracy is 0.734 and loss is 0.488
# 36/300 epoch: Accuracy is 0.859 and loss is 0.361
# 37/300 epoch: Accuracy is 0.766 and loss is 0.412
# 38/300 epoch: Accuracy is 0.781 and loss is 0.442
# 39/300 epoch: Accuracy is 0.781 and loss is 0.423
# 40/300 epoch: Accuracy is 0.719 and loss is 0.548
# 41/300 epoch: Accuracy is 0.781 and loss is 0.467
# 42/300 epoch: Accuracy is 0.844 and loss is 0.482
# 43/300 epoch: Accuracy is 0.781 and loss is 0.449
# 44/300 epoch: Accuracy is 0.766 and loss is 0.485
# 45/300 epoch: Accuracy is 0.922 and loss is 0.322
# 46/300 epoch: Accuracy is 0.781 and loss is 0.423
# 47/300 epoch: Accuracy is 0.875 and loss is 0.347
# 48/300 epoch: Accuracy is 0.797 and loss is 0.398
# 49/300 epoch: Accuracy is 0.797 and loss is 0.395
# 50/300 epoch: Accuracy is 0.828 and loss is 0.345
# 51/300 epoch: Accuracy is 0.875 and loss is 0.357
# 52/300 epoch: Accuracy is 0.828 and loss is 0.436
# 53/300 epoch: Accuracy is 0.797 and loss is 0.500
# 54/300 epoch: Accuracy is 0.750 and loss is 0.475
# 55/300 epoch: Accuracy is 0.797 and loss is 0.480
# 56/300 epoch: Accuracy is 0.797 and loss is 0.436
# 57/300 epoch: Accuracy is 0.797 and loss is 0.464
# 58/300 epoch: Accuracy is 0.703 and loss is 0.534
# 59/300 epoch: Accuracy is 0.703 and loss is 0.565
# 60/300 epoch: Accuracy is 0.797 and loss is 0.495
# 61/300 epoch: Accuracy is 0.844 and loss is 0.347
# 62/300 epoch: Accuracy is 0.859 and loss is 0.356
# 63/300 epoch: Accuracy is 0.781 and loss is 0.423
# 64/300 epoch: Accuracy is 0.719 and loss is 0.569
# 65/300 epoch: Accuracy is 0.844 and loss is 0.344
# 66/300 epoch: Accuracy is 0.797 and loss is 0.451
# 67/300 epoch: Accuracy is 0.766 and loss is 0.439
# 68/300 epoch: Accuracy is 0.750 and loss is 0.523
# 69/300 epoch: Accuracy is 0.734 and loss is 0.520
# 70/300 epoch: Accuracy is 0.828 and loss is 0.365
# 71/300 epoch: Accuracy is 0.781 and loss is 0.439
# 72/300 epoch: Accuracy is 0.766 and loss is 0.532
# 73/300 epoch: Accuracy is 0.781 and loss is 0.448
# 74/300 epoch: Accuracy is 0.781 and loss is 0.431
# 75/300 epoch: Accuracy is 0.828 and loss is 0.421
# 76/300 epoch: Accuracy is 0.844 and loss is 0.445
# 77/300 epoch: Accuracy is 0.719 and loss is 0.511
# 78/300 epoch: Accuracy is 0.859 and loss is 0.376
# 79/300 epoch: Accuracy is 0.688 and loss is 0.551
# 80/300 epoch: Accuracy is 0.688 and loss is 0.551
# 81/300 epoch: Accuracy is 0.891 and loss is 0.289
# 82/300 epoch: Accuracy is 0.797 and loss is 0.399
# 83/300 epoch: Accuracy is 0.797 and loss is 0.419
# 84/300 epoch: Accuracy is 0.844 and loss is 0.390
# 85/300 epoch: Accuracy is 0.766 and loss is 0.479
# 86/300 epoch: Accuracy is 0.844 and loss is 0.347
# 87/300 epoch: Accuracy is 0.797 and loss is 0.476
# 88/300 epoch: Accuracy is 0.828 and loss is 0.455
# 89/300 epoch: Accuracy is 0.781 and loss is 0.470
# 90/300 epoch: Accuracy is 0.844 and loss is 0.381
# 91/300 epoch: Accuracy is 0.750 and loss is 0.478
# 92/300 epoch: Accuracy is 0.766 and loss is 0.471
# 93/300 epoch: Accuracy is 0.781 and loss is 0.437
# 94/300 epoch: Accuracy is 0.641 and loss is 0.521
# 95/300 epoch: Accuracy is 0.750 and loss is 0.467
# 96/300 epoch: Accuracy is 0.812 and loss is 0.422
# 97/300 epoch: Accuracy is 0.766 and loss is 0.415
# 98/300 epoch: Accuracy is 0.766 and loss is 0.454
# 99/300 epoch: Accuracy is 0.844 and loss is 0.371
# 100/300 epoch: Accuracy is 0.875 and loss is 0.347
# 101/300 epoch: Accuracy is 0.844 and loss is 0.370
# 102/300 epoch: Accuracy is 0.797 and loss is 0.347
# 103/300 epoch: Accuracy is 0.766 and loss is 0.420
# 104/300 epoch: Accuracy is 0.750 and loss is 0.445
# 105/300 epoch: Accuracy is 0.812 and loss is 0.384
# 106/300 epoch: Accuracy is 0.844 and loss is 0.326
# 107/300 epoch: Accuracy is 0.828 and loss is 0.441
# 108/300 epoch: Accuracy is 0.781 and loss is 0.456
# 109/300 epoch: Accuracy is 0.734 and loss is 0.522
# 110/300 epoch: Accuracy is 0.828 and loss is 0.416
# 111/300 epoch: Accuracy is 0.859 and loss is 0.361
# 112/300 epoch: Accuracy is 0.812 and loss is 0.423
# 113/300 epoch: Accuracy is 0.688 and loss is 0.570
# 114/300 epoch: Accuracy is 0.875 and loss is 0.353
# 115/300 epoch: Accuracy is 0.766 and loss is 0.484
# 116/300 epoch: Accuracy is 0.781 and loss is 0.427
# 117/300 epoch: Accuracy is 0.688 and loss is 0.656
# 118/300 epoch: Accuracy is 0.766 and loss is 0.498
# 119/300 epoch: Accuracy is 0.797 and loss is 0.448
# 120/300 epoch: Accuracy is 0.750 and loss is 0.564
# 121/300 epoch: Accuracy is 0.844 and loss is 0.352
# 122/300 epoch: Accuracy is 0.766 and loss is 0.420
# 123/300 epoch: Accuracy is 0.797 and loss is 0.452
# 124/300 epoch: Accuracy is 0.812 and loss is 0.392
# 125/300 epoch: Accuracy is 0.797 and loss is 0.396
# 126/300 epoch: Accuracy is 0.828 and loss is 0.411
# 127/300 epoch: Accuracy is 0.797 and loss is 0.480
# 128/300 epoch: Accuracy is 0.797 and loss is 0.418
# 129/300 epoch: Accuracy is 0.797 and loss is 0.435
# 130/300 epoch: Accuracy is 0.766 and loss is 0.471
# 131/300 epoch: Accuracy is 0.828 and loss is 0.374
# 132/300 epoch: Accuracy is 0.828 and loss is 0.405
# 133/300 epoch: Accuracy is 0.906 and loss is 0.320
# 134/300 epoch: Accuracy is 0.703 and loss is 0.545
# 135/300 epoch: Accuracy is 0.797 and loss is 0.436
# 136/300 epoch: Accuracy is 0.875 and loss is 0.319
# 137/300 epoch: Accuracy is 0.781 and loss is 0.474
# 138/300 epoch: Accuracy is 0.719 and loss is 0.495
# 139/300 epoch: Accuracy is 0.812 and loss is 0.428
# 140/300 epoch: Accuracy is 0.766 and loss is 0.433
# 141/300 epoch: Accuracy is 0.844 and loss is 0.381
# 142/300 epoch: Accuracy is 0.844 and loss is 0.384
# 143/300 epoch: Accuracy is 0.828 and loss is 0.421
# 144/300 epoch: Accuracy is 0.797 and loss is 0.433
# 145/300 epoch: Accuracy is 0.766 and loss is 0.505
# 146/300 epoch: Accuracy is 0.828 and loss is 0.389
# 147/300 epoch: Accuracy is 0.797 and loss is 0.434
# 148/300 epoch: Accuracy is 0.766 and loss is 0.535
# 149/300 epoch: Accuracy is 0.812 and loss is 0.455
# 150/300 epoch: Accuracy is 0.719 and loss is 0.450
# 151/300 epoch: Accuracy is 0.828 and loss is 0.389
# 152/300 epoch: Accuracy is 0.734 and loss is 0.428
# 153/300 epoch: Accuracy is 0.875 and loss is 0.352
# 154/300 epoch: Accuracy is 0.859 and loss is 0.395
# 155/300 epoch: Accuracy is 0.781 and loss is 0.420
# 156/300 epoch: Accuracy is 0.719 and loss is 0.514
# 157/300 epoch: Accuracy is 0.828 and loss is 0.388
# 158/300 epoch: Accuracy is 0.859 and loss is 0.343
# 159/300 epoch: Accuracy is 0.703 and loss is 0.586
# 160/300 epoch: Accuracy is 0.734 and loss is 0.466
# 161/300 epoch: Accuracy is 0.906 and loss is 0.331
# 162/300 epoch: Accuracy is 0.781 and loss is 0.445
# 163/300 epoch: Accuracy is 0.750 and loss is 0.432
# 164/300 epoch: Accuracy is 0.766 and loss is 0.450
# 165/300 epoch: Accuracy is 0.750 and loss is 0.535
# 166/300 epoch: Accuracy is 0.766 and loss is 0.439
# 167/300 epoch: Accuracy is 0.891 and loss is 0.348
# 168/300 epoch: Accuracy is 0.844 and loss is 0.321
# 169/300 epoch: Accuracy is 0.766 and loss is 0.419
# 170/300 epoch: Accuracy is 0.875 and loss is 0.288
# 171/300 epoch: Accuracy is 0.766 and loss is 0.485
# 172/300 epoch: Accuracy is 0.828 and loss is 0.422
# 173/300 epoch: Accuracy is 0.797 and loss is 0.429
# 174/300 epoch: Accuracy is 0.828 and loss is 0.441
# 175/300 epoch: Accuracy is 0.859 and loss is 0.369
# 176/300 epoch: Accuracy is 0.844 and loss is 0.421
# 177/300 epoch: Accuracy is 0.812 and loss is 0.453
# 178/300 epoch: Accuracy is 0.781 and loss is 0.440
# 179/300 epoch: Accuracy is 0.797 and loss is 0.446
# 180/300 epoch: Accuracy is 0.859 and loss is 0.357
# 181/300 epoch: Accuracy is 0.859 and loss is 0.367
# 182/300 epoch: Accuracy is 0.844 and loss is 0.418
# 183/300 epoch: Accuracy is 0.891 and loss is 0.340
# 184/300 epoch: Accuracy is 0.734 and loss is 0.411
# 185/300 epoch: Accuracy is 0.781 and loss is 0.418
# 186/300 epoch: Accuracy is 0.844 and loss is 0.410
# 187/300 epoch: Accuracy is 0.797 and loss is 0.486
# 188/300 epoch: Accuracy is 0.812 and loss is 0.462
# 189/300 epoch: Accuracy is 0.781 and loss is 0.435
# 190/300 epoch: Accuracy is 0.750 and loss is 0.475
# 191/300 epoch: Accuracy is 0.781 and loss is 0.430
# 192/300 epoch: Accuracy is 0.812 and loss is 0.417
# 193/300 epoch: Accuracy is 0.797 and loss is 0.435
# 194/300 epoch: Accuracy is 0.750 and loss is 0.440
# 195/300 epoch: Accuracy is 0.844 and loss is 0.401
# 196/300 epoch: Accuracy is 0.781 and loss is 0.449
# 197/300 epoch: Accuracy is 0.734 and loss is 0.511
# 198/300 epoch: Accuracy is 0.875 and loss is 0.352
# 199/300 epoch: Accuracy is 0.812 and loss is 0.446
# 200/300 epoch: Accuracy is 0.844 and loss is 0.381
# 201/300 epoch: Accuracy is 0.859 and loss is 0.387
# 202/300 epoch: Accuracy is 0.781 and loss is 0.446
# 203/300 epoch: Accuracy is 0.859 and loss is 0.343
# 204/300 epoch: Accuracy is 0.781 and loss is 0.463
# 205/300 epoch: Accuracy is 0.734 and loss is 0.458
# 206/300 epoch: Accuracy is 0.844 and loss is 0.439
# 207/300 epoch: Accuracy is 0.859 and loss is 0.353
# 208/300 epoch: Accuracy is 0.828 and loss is 0.383
# 209/300 epoch: Accuracy is 0.812 and loss is 0.437
# 210/300 epoch: Accuracy is 0.859 and loss is 0.348
# 211/300 epoch: Accuracy is 0.828 and loss is 0.400
# 212/300 epoch: Accuracy is 0.844 and loss is 0.366
# 213/300 epoch: Accuracy is 0.781 and loss is 0.432
# 214/300 epoch: Accuracy is 0.750 and loss is 0.413
# 215/300 epoch: Accuracy is 0.719 and loss is 0.528
# 216/300 epoch: Accuracy is 0.812 and loss is 0.367
# 217/300 epoch: Accuracy is 0.750 and loss is 0.437
# 218/300 epoch: Accuracy is 0.812 and loss is 0.401
# 219/300 epoch: Accuracy is 0.766 and loss is 0.414
# 220/300 epoch: Accuracy is 0.750 and loss is 0.426
# 221/300 epoch: Accuracy is 0.734 and loss is 0.467
# 222/300 epoch: Accuracy is 0.859 and loss is 0.369
# 223/300 epoch: Accuracy is 0.812 and loss is 0.431
# 224/300 epoch: Accuracy is 0.781 and loss is 0.476
# 225/300 epoch: Accuracy is 0.766 and loss is 0.452
# 226/300 epoch: Accuracy is 0.781 and loss is 0.487
# 227/300 epoch: Accuracy is 0.828 and loss is 0.377
# 228/300 epoch: Accuracy is 0.703 and loss is 0.549
# 229/300 epoch: Accuracy is 0.812 and loss is 0.393
# 230/300 epoch: Accuracy is 0.812 and loss is 0.394
# 231/300 epoch: Accuracy is 0.750 and loss is 0.513
# 232/300 epoch: Accuracy is 0.766 and loss is 0.442
# 233/300 epoch: Accuracy is 0.828 and loss is 0.421
# 234/300 epoch: Accuracy is 0.672 and loss is 0.509
# 235/300 epoch: Accuracy is 0.812 and loss is 0.372
# 236/300 epoch: Accuracy is 0.797 and loss is 0.414
# 237/300 epoch: Accuracy is 0.844 and loss is 0.435
# 238/300 epoch: Accuracy is 0.781 and loss is 0.495
# 239/300 epoch: Accuracy is 0.734 and loss is 0.487
# 240/300 epoch: Accuracy is 0.859 and loss is 0.362
# 241/300 epoch: Accuracy is 0.844 and loss is 0.417
# 242/300 epoch: Accuracy is 0.781 and loss is 0.474
# 243/300 epoch: Accuracy is 0.781 and loss is 0.407
# 244/300 epoch: Accuracy is 0.750 and loss is 0.471
# 245/300 epoch: Accuracy is 0.875 and loss is 0.337
# 246/300 epoch: Accuracy is 0.766 and loss is 0.448
# 247/300 epoch: Accuracy is 0.750 and loss is 0.429
# 248/300 epoch: Accuracy is 0.844 and loss is 0.346
# 249/300 epoch: Accuracy is 0.828 and loss is 0.360
# 250/300 epoch: Accuracy is 0.797 and loss is 0.444
# 251/300 epoch: Accuracy is 0.766 and loss is 0.492
# 252/300 epoch: Accuracy is 0.797 and loss is 0.463
# 253/300 epoch: Accuracy is 0.750 and loss is 0.539
# 254/300 epoch: Accuracy is 0.734 and loss is 0.438
# 255/300 epoch: Accuracy is 0.766 and loss is 0.481
# 256/300 epoch: Accuracy is 0.797 and loss is 0.382
# 257/300 epoch: Accuracy is 0.734 and loss is 0.533
# 258/300 epoch: Accuracy is 0.750 and loss is 0.503
# 259/300 epoch: Accuracy is 0.828 and loss is 0.384
# 260/300 epoch: Accuracy is 0.734 and loss is 0.460
# 261/300 epoch: Accuracy is 0.781 and loss is 0.500
# 262/300 epoch: Accuracy is 0.812 and loss is 0.448
# 263/300 epoch: Accuracy is 0.750 and loss is 0.475
# 264/300 epoch: Accuracy is 0.875 and loss is 0.317
# 265/300 epoch: Accuracy is 0.703 and loss is 0.515
# 266/300 epoch: Accuracy is 0.797 and loss is 0.462
# 267/300 epoch: Accuracy is 0.812 and loss is 0.401
# 268/300 epoch: Accuracy is 0.781 and loss is 0.407
# 269/300 epoch: Accuracy is 0.828 and loss is 0.404
# 270/300 epoch: Accuracy is 0.828 and loss is 0.356
# 271/300 epoch: Accuracy is 0.891 and loss is 0.312
# 272/300 epoch: Accuracy is 0.812 and loss is 0.335
# 273/300 epoch: Accuracy is 0.797 and loss is 0.394
# 274/300 epoch: Accuracy is 0.766 and loss is 0.485
# 275/300 epoch: Accuracy is 0.781 and loss is 0.371
# 276/300 epoch: Accuracy is 0.875 and loss is 0.321
# 277/300 epoch: Accuracy is 0.766 and loss is 0.493
# 278/300 epoch: Accuracy is 0.781 and loss is 0.428
# 279/300 epoch: Accuracy is 0.750 and loss is 0.512
# 280/300 epoch: Accuracy is 0.812 and loss is 0.364
# 281/300 epoch: Accuracy is 0.766 and loss is 0.459
# 282/300 epoch: Accuracy is 0.812 and loss is 0.408
# 283/300 epoch: Accuracy is 0.719 and loss is 0.448
# 284/300 epoch: Accuracy is 0.844 and loss is 0.366
# 285/300 epoch: Accuracy is 0.812 and loss is 0.376
# 286/300 epoch: Accuracy is 0.734 and loss is 0.509
# 287/300 epoch: Accuracy is 0.766 and loss is 0.416
# 288/300 epoch: Accuracy is 0.781 and loss is 0.428
# 289/300 epoch: Accuracy is 0.828 and loss is 0.401
# 290/300 epoch: Accuracy is 0.734 and loss is 0.468
# 291/300 epoch: Accuracy is 0.766 and loss is 0.426
# 292/300 epoch: Accuracy is 0.875 and loss is 0.367
# 293/300 epoch: Accuracy is 0.859 and loss is 0.354
# 294/300 epoch: Accuracy is 0.797 and loss is 0.431
# 295/300 epoch: Accuracy is 0.781 and loss is 0.501
# 296/300 epoch: Accuracy is 0.875 and loss is 0.356
# 297/300 epoch: Accuracy is 0.766 and loss is 0.392
# 298/300 epoch: Accuracy is 0.734 and loss is 0.487
# 299/300 epoch: Accuracy is 0.750 and loss is 0.490
